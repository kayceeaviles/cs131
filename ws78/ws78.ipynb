# %%
# %%time 

from pyspark.sql import SparkSession

# creating SparkSession instance
spark = SparkSession.builder.appName("MYAPP").getOrCreate()

# defining path from GCS
gcs_path = "gs://dataproc-staging-us-central1-325900183882-rh5w8gsb/datasets/data_sample.csv"

# reading csv file into Spark DataFrame
df = spark.read.csv(gcs_path, header=True, inferSchema=True)

df.show()
# Out:
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |               Breed|   AKC_group|Popularity_in_US|Intelligence|Longevity|Genetic_ailments|Avg_price|  Size|Weight (lbs)|Shoulder_height (in)|Intelligence_category|
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |       Border Collie|     herding|              45|           1|    12.52|               2|    623.0|medium|        50.0|                20.0|            Brightest|
# |      Border Terrier|     terrier|              80|          30|     14.0|               0|    833.0| small|        13.5|                 9.0|        Above average|
# ...

# %%
# %%time

from pyspark.sql import SparkSession

# creating SparkSession instance
spark = SparkSession.builder.appName("MYAPP").getOrCreate()

# defining path from GCS
gcs_path = "gs://dataproc-staging-us-central1-325900183882-rh5w8gsb/datasets/data_sample2.csv"

# reading csv file into Spark DataFrame
df = spark.read.csv(gcs_path, header=True, inferSchema=True)

df.show()
# Out:
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |               Breed|   AKC_group|Popularity_in_US|Intelligence|Longevity|Genetic_ailments|Avg_price|  Size|Weight (lbs)|Shoulder_height (in)|Intelligence_category|
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |       Border Collie|     herding|              45|           1|    12.52|               2|    623.0|medium|        50.0|                20.0|            Brightest|
# |      Border Terrier|     terrier|              80|          30|     14.0|               0|    833.0| small|        13.5|                 9.0|        Above average|
# ...

# %%
# %%time

from pyspark.sql import SparkSession

# creating SparkSession instance
spark = SparkSession.builder.appName("MYAPP").getOrCreate()

# defining path from GCS
gcs_path = "gs://dataproc-staging-us-central1-325900183882-rh5w8gsb/datasets/data_sample3.csv"

# reading csv file into Spark DataFrame
df = spark.read.csv(gcs_path, header=True, inferSchema=True)

df.show()
# Out:
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |               Breed|   AKC_group|Popularity_in_US|Intelligence|Longevity|Genetic_ailments|Avg_price|  Size|Weight (lbs)|Shoulder_height (in)|Intelligence_category|
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |Black Russian Ter...|     working|             128|          42|     12.0|               0|    533.0| large|        82.0|                28.0|              Average|
# |  Bluetick Coonhound|       hound|             136|          43|     11.0|               0|    370.0| large|        62.5|                24.0|              Average|
# ...

# %%
# %%time

from pyspark.sql import SparkSession

# creating SparkSession instance
spark = SparkSession.builder.appName("MYAPP").getOrCreate()

# defining path from GCS
gcs_path = "gs://dataproc-staging-us-central1-325900183882-rh5w8gsb/datasets/data_sample4.csv"

# reading csv file into Spark DataFrame
df = spark.read.csv(gcs_path, header=True, inferSchema=True)

df.show()
# Out:
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |               Breed|   AKC_group|Popularity_in_US|Intelligence|Longevity|Genetic_ailments|Avg_price|  Size|Weight (lbs)|Shoulder_height (in)|Intelligence_category|
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |       Border Collie|     herding|              45|           1|    12.52|               2|    623.0|medium|        50.0|                20.0|            Brightest|
# |      Border Terrier|     terrier|              80|          30|     14.0|               0|    833.0| small|        13.5|                 9.0|        Above average|
# ...

# %%
# %%time

from pyspark.sql import SparkSession

# creating SparkSession instance
spark = SparkSession.builder.appName("MYAPP").getOrCreate()

# defining path from GCS
gcs_path = "gs://dataproc-staging-us-central1-325900183882-rh5w8gsb/datasets/data_sample5.csv"

# reading csv file into Spark DataFrame
df = spark.read.csv(gcs_path, header=True, inferSchema=True)

df.show()
# Out:
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |               Breed|   AKC_group|Popularity_in_US|Intelligence|Longevity|Genetic_ailments|Avg_price|  Size|Weight (lbs)|Shoulder_height (in)|Intelligence_category|
# +--------------------+------------+----------------+------------+---------+----------------+---------+------+------------+--------------------+---------------------+
# |       Border Collie|     herding|              45|           1|    12.52|               2|    623.0|medium|        50.0|                20.0|            Brightest|
# |      Border Terrier|     terrier|              80|          30|     14.0|               0|    833.0| small|        13.5|                 9.0|        Above average|
# ...
